# %% [markdown]
# # Clean incident-retrieval model selection
#
# This notebook compares BM25, MiniLM, and Mixedbread using the clean agent's frozen retrieval contract. It does not need Kubernetes, Redis, n8n, the dashboard, or an API key.
#
# ## What is being tested
#
# `evidence -> stable EvidenceTemplate -> fingerprint exact check -> BM25 candidates -> optional local reranker`
#
# Each stored example contains evidence plus approved hints. Exact fingerprints bypass reranking; all other cases produce one of `exact / nearest / none / degraded`. MiniLM and Mixedbread receive the same BM25 candidate set.
#
# The LLM judge is intentionally excluded: it is outside the local retrieval comparison and adds provider cost, latency, and non-determinism.

# %% [markdown]
# ## 1. Get the clean code and lightweight dependency
#
# Restart the Colab runtime, then use **Runtime → Run all**. Model-specific dependencies are installed in a later section.

# %%
# !git clone https://github.com/Ama2352/vroom-services.git
# %cd /content/vroom-services/incident-diagnosis/evaluation
# !pip -q install rank-bm25
# Out:
# Cloning into 'vroom-services'...
# remote: Enumerating objects: 4225, done.
# remote: Counting objects: 100% (581/581), done.
# remote: Compressing objects: 100% (354/354), done.
# remote: Total 4225 (delta 292), reused 471 (delta 213), pack-reused 3644 (from 1)
# Receiving objects: 100% (4225/4225), 4.55 MiB | 7.18 MiB/s, done.
# Resolving deltas: 100% (2526/2526), done.
# /content/vroom-services/incident-diagnosis/evaluation

# %% [markdown]
# ## 2. Load the frozen cases
#
# `historical_context_enriched_snapshot.json` keeps the clean `families`, `examples`, and `hints` schema while adding archived runbook context as approved historical hints. No production data is read or changed.

# %%
from pathlib import Path
import sys

EVALUATION_ROOT = Path.cwd()
AGENT_ROOT = EVALUATION_ROOT.parent / 'agent'
sys.path[:0] = [str(AGENT_ROOT), str(EVALUATION_ROOT)]

from benchmark import evidence_category_coverage, field_coverage, load_cases, load_snapshot, pipeline_trace, validate_semantic_cases

cases = load_cases(EVALUATION_ROOT / 'fixtures' / 'retrieval_cases.json')
semantic_cases = load_cases(EVALUATION_ROOT / 'fixtures' / 'semantic_disambiguation_cases.json')
snapshot = load_snapshot(EVALUATION_ROOT / 'fixtures' / 'historical_context_enriched_snapshot.json')
validate_semantic_cases(semantic_cases, snapshot)
calibration_cases = tuple(case for case in cases if case.split == 'calibration')
held_out_cases = tuple(case for case in cases if case.split == 'held_out')
held_out_positive_cases = tuple(case for case in held_out_cases if case.expected_mode != 'none')
held_out_no_match_cases = tuple(case for case in held_out_cases if case.expected_mode == 'none')
assert len(cases) == 40
assert len(calibration_cases) == len(held_out_cases) == 20
assert len(held_out_positive_cases) == len(held_out_no_match_cases) == 10
print(f'{len(cases)} frozen cases; {len(snapshot["examples"])} approved examples')
print(f'{len(held_out_positive_cases)} held-out positive cases; {len(held_out_no_match_cases)} held-out no-match cases')
for benchmark_name, benchmark_cases in [('Historical', cases), ('Semantic', semantic_cases)]:
    coverage = field_coverage(benchmark_cases)
    print(f'{benchmark_name} field coverage:', {field: f'{value:.0%}' for field, value in coverage.items()})
print('Evidence categories:', evidence_category_coverage((*cases, *semantic_cases)))
# Out:
# 40 frozen cases; 26 approved examples
# 10 held-out positive cases; 10 held-out no-match cases
# Historical field coverage: {'service': '0%', 'triggering_metric': '100%', 'log_error': '78%', 'trace_error_service': '0%', 'trace_error_operation': '0%', 'trace_error_message': '0%', 'configuration_diff': '0%'}
# Semantic field coverage: {'service': '69%', 'triggering_metric': '100%', 'log_error': '88%', 'trace_error_service': '12%', 'trace_error_operation': '12%', 'trace_error_message': '12%', 'configuration_diff': '12%'}
# Evidence categories: {'kubernetes_heavy': 18, 'metrics_plus_logs': 45, 'logs_plus_traces': 2, 'configuration_related': 2, 'sparse_no_match': 12, 'conflicting_evidence': 9}

# %% [markdown]
# ## 3. Download pinned local rerankers
#
# The download is revision-pinned and the ONNX artifact is checksum-verified. These models stay local to the Colab runtime.

# %%
# !pip -q install transformers onnxruntime huggingface_hub numpy matplotlib psutil

from huggingface_hub import snapshot_download
from reranker import MiniLMReranker, ModelSpec, OnnxCrossEncoder, verify_sha256
from benchmark import IdentityReranker, calibrate_score_floor, evaluate_selection_gate, load_model_specs, retrieve_case, run_system

model_specs = load_model_specs(EVALUATION_ROOT / 'model_specs.json')

def download_model(name):
    spec = model_specs[name]
    model_dir = Path(snapshot_download(
        repo_id=spec['repo_id'], revision=spec['revision'],
        allow_patterns=['*.json', '*.txt', '*.model', 'onnx/*.onnx'],
    ))
    verify_sha256(model_dir / spec['onnx_file'], spec['sha256'])
    return model_dir, spec

def build_reranker(model_dir, spec):
    backend = OnnxCrossEncoder(model_dir, ModelSpec(**spec))
    return MiniLMReranker(backend)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 69.3 MB/s eta 0:00:00

# %% [markdown]
# ## 4. Run the same pipeline for every system
#
# BM25 selects candidates first. The two neural models can only reorder that same small candidate set. Exact fingerprint matches bypass every reranker.

# %%
import json
import numpy as np
import subprocess

def measure_local_system(name):
    model_dir, _spec = download_model(name)
    # Probe in a new process so another loaded model cannot inflate RSS.
    completed = subprocess.run(
        [sys.executable, 'resource_probe.py', '--name', name, '--model-dir', str(model_dir)],
        check=True, capture_output=True, text=True,
    )
    return json.loads(completed.stdout)

bm25 = IdentityReranker()
bm25_floor = calibrate_score_floor(cases, snapshot, bm25, name='bm25')
if not np.isfinite(bm25_floor):
    raise RuntimeError('BM25 could not find a safe calibration threshold.')
results = {'bm25': run_system(held_out_cases, snapshot, bm25, name='bm25', score_floor=bm25_floor)}
operations = {'bm25': {'artifact_mb': 0.0, 'cold_load_ms': 0.0, 'p50_ms': 0.0, 'p95_ms': 0.0, 'peak_rss_mb': 0.0}}
score_floors = {'bm25': bm25_floor}
rerankers = {'bm25': bm25}
unavailable = {}

for name in ('minilm', 'mixedbread_xsmall'):
    try:
        operations[name] = measure_local_system(name)
        reranker = build_reranker(*download_model(name))
        rerankers[name] = reranker
        floor = calibrate_score_floor(cases, snapshot, reranker, name=name)
        if not np.isfinite(floor):
            raise RuntimeError('could not find a safe calibration threshold')
        score_floors[name] = floor
        results[name] = run_system(held_out_cases, snapshot, reranker, name=name, score_floor=floor)
    except Exception as exc:
        unavailable[name] = f'{type(exc).__name__}: {exc}'

assert all(result.advisory_positive_count == len(held_out_positive_cases) for result in results.values())
semantic_results = {
    name: run_system(semantic_cases, snapshot, rerankers[name], name=name, score_floor=score_floors[name])
    for name in results
}
semantic_provenance_results = {
    provenance: {name: run_system(tuple(case for case in semantic_cases if case.provenance == provenance), snapshot, rerankers[name], name=name, score_floor=score_floors[name]) for name in results}
    for provenance in ('archive_derived', 'synthetic_stress')
}
print('Calibration score floors:', score_floors)
print('Unavailable systems:', unavailable or 'none')
# Out:
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 14 files:   0%|          | 0/14 [00:00<?, ?it/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Calibration score floors: {'bm25': 9.139915471922995, 'minilm': 7.159183502197266, 'mixedbread_xsmall': 0.8416229486465454}
# Unavailable systems: none

# %% [markdown]
# ## 5. Quality metrics
#
# Both benchmarks report exact correctness, Top-1, MRR, Recall@3, false positives, and abstentions. The semantic slice contains keyword-sharing competitors; Top-1 and MRR are its primary measures. A confusion matrix is intentionally omitted because this is a retrieval-ranking comparison with multiple valid candidates and abstentions, not a single-label classifier.

# %%
import matplotlib.pyplot as plt

def ratio(numerator, denominator):
    return numerator / denominator if denominator else 0.0

names = list(results)
display_names = {
    'bm25': 'BM25 only',
    'minilm': 'BM25 → MiniLM',
    'mixedbread_xsmall': 'BM25 → Mixedbread',
}
quality = {
    name: [
        ratio(result.advisory_top1, result.advisory_positive_count),
        ratio(result.advisory_recall_at_3, result.advisory_positive_count),
        ratio(result.advisory_mrr_sum, result.advisory_positive_count),
    ]
    for name, result in results.items()
}

labels = ['Advisory Top-1', 'Recall@3', 'MRR']
x = np.arange(len(labels))
width = 0.8 / len(names)
fig, ax = plt.subplots(figsize=(10, 4))
for index, name in enumerate(names):
    ax.bar(x - 0.4 + width / 2 + index * width, quality[name], width, label=display_names[name])
ax.set_xticks(x, labels)
ax.set_ylim(0, 1.05)
ax.set_ylabel('Score')
ax.set_title('Held-out advisory quality metrics')
ax.legend()
plt.show()
print('Exact fingerprint cases are calibration-only; they are not plotted as held-out ranking quality.')

semantic_quality = {
    name: [ratio(result.advisory_top1, result.advisory_positive_count), ratio(result.advisory_recall_at_3, result.advisory_positive_count), ratio(result.advisory_mrr_sum, result.advisory_positive_count)]
    for name, result in semantic_results.items()
}
fig, ax = plt.subplots(figsize=(10, 4))
for index, name in enumerate(names):
    ax.bar(x - 0.4 + width / 2 + index * width, semantic_quality[name], width, label=display_names[name])
ax.set_xticks(x, labels)
ax.set_ylim(0, 1.05)
ax.set_ylabel('Score')
ax.set_title('Semantic-disambiguation quality metrics')
ax.legend()
plt.show()

for benchmark_name, benchmark_results in [('Historical', results), ('Semantic', semantic_results)]:
    print(f'\n{benchmark_name} benchmark')
    for name, result in benchmark_results.items():
        print(f'{display_names[name]:20} exact={result.exact_correct}/{result.exact_total} top1={ratio(result.advisory_top1, result.advisory_positive_count):.2f} mrr={ratio(result.advisory_mrr_sum, result.advisory_positive_count):.2f} recall@3={ratio(result.advisory_recall_at_3, result.advisory_positive_count):.2f} false_positives={result.false_positives} abstentions={result.correct_abstentions}')

for provenance, provenance_results in semantic_provenance_results.items():
    print(f'\nSemantic provenance: {provenance} (not historical unless archive_derived)')
    for name, result in provenance_results.items():
        print(f'{display_names[name]:20} top1={ratio(result.advisory_top1, result.advisory_positive_count):.2f} mrr={ratio(result.advisory_mrr_sum, result.advisory_positive_count):.2f} recall@3={ratio(result.advisory_recall_at_3, result.advisory_positive_count):.2f} false_positives={result.false_positives} abstentions={result.correct_abstentions}')

print('\nSemantic pipeline traces (BM25 → raw reranker → threshold → accepted):')
for case in semantic_cases:
    print(f'\n{case.case_id}: expected={case.expected_keys}; competitors={case.competing_keys}')
    for name in names:
        print(display_names[name], pipeline_trace(case, snapshot, rerankers[name], name=name, score_floor=score_floors[name]))
# Out:
# Exact fingerprint cases are calibration-only; they are not plotted as held-out ranking quality.
# Historical benchmark
# BM25 only            exact=0/0 top1=1.00 mrr=1.00 recall@3=1.00 false_positives=0 abstentions=10
# BM25 → MiniLM        exact=0/0 top1=0.60 mrr=0.60 recall@3=0.60 false_positives=0 abstentions=10
# BM25 → Mixedbread    exact=0/0 top1=0.30 mrr=0.30 recall@3=0.30 false_positives=0 abstentions=10
#
# Semantic benchmark
# BM25 only            exact=0/0 top1=0.69 mrr=0.75 recall@3=0.81 false_positives=0 abstentions=0
# BM25 → MiniLM        exact=0/0 top1=0.12 mrr=0.12 recall@3=0.12 false_positives=0 abstentions=0
# BM25 → Mixedbread    exact=0/0 top1=0.19 mrr=0.19 recall@3=0.19 false_positives=0 abstentions=0
#
# Semantic provenance: archive_derived (not historical unless archive_derived)
# BM25 only            top1=1.00 mrr=1.00 recall@3=1.00 false_positives=0 abstentions=0
# BM25 → MiniLM        top1=0.25 mrr=0.25 recall@3=0.25 false_positives=0 abstentions=0
# BM25 → Mixedbread    top1=0.25 mrr=0.25 recall@3=0.25 false_positives=0 abstentions=0
#
# Semantic provenance: synthetic_stress (not historical unless archive_derived)
# BM25 only            top1=0.38 mrr=0.50 recall@3=0.62 false_positives=0 abstentions=0
# BM25 → MiniLM        top1=0.00 mrr=0.00 recall@3=0.00 false_positives=0 abstentions=0
# BM25 → Mixedbread    top1=0.12 mrr=0.12 recall@3=0.12 false_positives=0 abstentions=0
#
# Semantic pipeline traces (BM25 → raw reranker → threshold → accepted):
#
# semantic_init_bootstrap: expected=('init_crashloop',); competitors=('crashloop', 'config_error')
# BM25 only {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 13.611114020677228, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'init', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 10.696876900149148, 'reranker': 0.0, 'matched_terms': ('after', 'configuration', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_oom', 'bm25': 4.101139648407863, 'reranker': 0.0, 'matched_terms': ('init',)}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 13.611114020677228, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'init', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 10.696876900149148, 'reranker': 0.0, 'matched_terms': ('after', 'configuration', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_oom', 'bm25': 4.101139648407863, 'reranker': 0.0, 'matched_terms': ('init',)}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'init_crashloop', 'bm25': 13.611114020677228, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'init', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 10.696876900149148, 'reranker': 0.0, 'matched_terms': ('after', 'configuration', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 13.611114020677228, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'init', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 10.696876900149148, 'reranker': 0.0, 'matched_terms': ('after', 'configuration', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_oom', 'bm25': 4.101139648407863, 'reranker': 0.0, 'matched_terms': ('init',)}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 13.611114020677228, 'reranker': 6.645625591278076, 'matched_terms': ('crashloopbackoff', 'init', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 10.696876900149148, 'reranker': 6.669628143310547, 'matched_terms': ('after', 'configuration', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_oom', 'bm25': 4.101139648407863, 'reranker': 5.813248634338379, 'matched_terms': ('init',)}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 13.611114020677228, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'init', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 10.696876900149148, 'reranker': 0.0, 'matched_terms': ('after', 'configuration', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_oom', 'bm25': 4.101139648407863, 'reranker': 0.0, 'matched_terms': ('init',)}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 13.611114020677228, 'reranker': 0.7381981611251831, 'matched_terms': ('crashloopbackoff', 'init', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 10.696876900149148, 'reranker': 0.8873268365859985, 'matched_terms': ('after', 'configuration', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_oom', 'bm25': 4.101139648407863, 'reranker': 0.46547970175743103, 'matched_terms': ('init',)}], 'score_floor': 0.8416229486465454, 'accepted_candidates': [{'key': 'crashloop', 'bm25': 10.696876900149148, 'reranker': 0.8873268365859985, 'matched_terms': ('after', 'configuration', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}]}
#
# semantic_secret_startup: expected=('config_error',); competitors=('crashloop', 'init_crashloop')
# BM25 only {'bm25_candidates': [{'key': 'config_error', 'bm25': 15.772587433074976, 'reranker': 0.0, 'matched_terms': ('createcontainerconfigerror', 'failed', 'kubepodcontainerwaiting', 'secret')}, {'key': 'crashloop', 'bm25': 11.96068624792336, 'reranker': 0.0, 'matched_terms': ('application', 'configuration', 'container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}], 'raw_reranker_candidates': [{'key': 'config_error', 'bm25': 15.772587433074976, 'reranker': 0.0, 'matched_terms': ('createcontainerconfigerror', 'failed', 'kubepodcontainerwaiting', 'secret')}, {'key': 'crashloop', 'bm25': 11.96068624792336, 'reranker': 0.0, 'matched_terms': ('application', 'configuration', 'container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'config_error', 'bm25': 15.772587433074976, 'reranker': 0.0, 'matched_terms': ('createcontainerconfigerror', 'failed', 'kubepodcontainerwaiting', 'secret')}, {'key': 'crashloop', 'bm25': 11.96068624792336, 'reranker': 0.0, 'matched_terms': ('application', 'configuration', 'container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'config_error', 'bm25': 15.772587433074976, 'reranker': 0.0, 'matched_terms': ('createcontainerconfigerror', 'failed', 'kubepodcontainerwaiting', 'secret')}, {'key': 'crashloop', 'bm25': 11.96068624792336, 'reranker': 0.0, 'matched_terms': ('application', 'configuration', 'container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}], 'raw_reranker_candidates': [{'key': 'config_error', 'bm25': 15.772587433074976, 'reranker': 6.310617446899414, 'matched_terms': ('createcontainerconfigerror', 'failed', 'kubepodcontainerwaiting', 'secret')}, {'key': 'crashloop', 'bm25': 11.96068624792336, 'reranker': 6.1847052574157715, 'matched_terms': ('application', 'configuration', 'container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 6.397339820861816, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'config_error', 'bm25': 15.772587433074976, 'reranker': 0.0, 'matched_terms': ('createcontainerconfigerror', 'failed', 'kubepodcontainerwaiting', 'secret')}, {'key': 'crashloop', 'bm25': 11.96068624792336, 'reranker': 0.0, 'matched_terms': ('application', 'configuration', 'container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}], 'raw_reranker_candidates': [{'key': 'config_error', 'bm25': 15.772587433074976, 'reranker': 0.7070170640945435, 'matched_terms': ('createcontainerconfigerror', 'failed', 'kubepodcontainerwaiting', 'secret')}, {'key': 'crashloop', 'bm25': 11.96068624792336, 'reranker': 0.7557682394981384, 'matched_terms': ('application', 'configuration', 'container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.7529191374778748, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# semantic_outbox_pending: expected=('outbox_not_draining',); competitors=('xautoclaim_pel_backlog',)
# BM25 only {'bm25_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 0.0, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 10.628837609251335, 'reranker': 0.0, 'matched_terms': ('acknowledged', 'not', 'pending')}, {'key': 'driver_matching_returns_0_results', 'bm25': 5.119792154965655, 'reranker': 0.0, 'matched_terms': ('is', 'redis')}], 'raw_reranker_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 0.0, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 10.628837609251335, 'reranker': 0.0, 'matched_terms': ('acknowledged', 'not', 'pending')}, {'key': 'driver_matching_returns_0_results', 'bm25': 5.119792154965655, 'reranker': 0.0, 'matched_terms': ('is', 'redis')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 0.0, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 10.628837609251335, 'reranker': 0.0, 'matched_terms': ('acknowledged', 'not', 'pending')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 0.0, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 10.628837609251335, 'reranker': 0.0, 'matched_terms': ('acknowledged', 'not', 'pending')}, {'key': 'driver_matching_returns_0_results', 'bm25': 5.119792154965655, 'reranker': 0.0, 'matched_terms': ('is', 'redis')}], 'raw_reranker_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 7.391185283660889, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 10.628837609251335, 'reranker': 5.761135101318359, 'matched_terms': ('acknowledged', 'not', 'pending')}, {'key': 'kargo_verification_failing', 'bm25': 3.5815583394054595, 'reranker': 4.696730613708496, 'matched_terms': ('blocked',)}], 'score_floor': 7.159183502197266, 'accepted_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 7.391185283660889, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}]}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 0.0, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 10.628837609251335, 'reranker': 0.0, 'matched_terms': ('acknowledged', 'not', 'pending')}, {'key': 'driver_matching_returns_0_results', 'bm25': 5.119792154965655, 'reranker': 0.0, 'matched_terms': ('is', 'redis')}], 'raw_reranker_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 1.020072340965271, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 10.628837609251335, 'reranker': 0.6810429096221924, 'matched_terms': ('acknowledged', 'not', 'pending')}, {'key': 'trip_offer_timeout_storm', 'bm25': 4.435184813466074, 'reranker': 0.29312220215797424, 'matched_terms': ('are', 'is', 'the')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': [{'key': 'outbox_not_draining', 'bm25': 18.849322413797424, 'reranker': 1.020072340965271, 'matched_terms': ('are', 'blocked', 'is', 'outbox', 'outboxbacklog', 'pending', 'redis', 'stream', 'the')}]}
#
# semantic_argocd_promotion: expected=('argocd_app_stuck_outofsync',); competitors=('kargo_verification_failing',)
# BM25 only {'bm25_candidates': [{'key': 'argocd_app_stuck_outofsync', 'bm25': 28.78656639874839, 'reranker': 0.0, 'matched_terms': ('apply', 'argocdappoutofsync', 'by', 'conflict', 'field', 'manager', 'outofsync', 'server', 'side')}, {'key': 'kargo_verification_failing', 'bm25': 7.163116678810919, 'reranker': 0.0, 'matched_terms': ('blocked', 'promotion')}, {'key': 'outbox_not_draining', 'bm25': 1.8198454615906146, 'reranker': 0.0, 'matched_terms': ('blocked',)}], 'raw_reranker_candidates': [{'key': 'argocd_app_stuck_outofsync', 'bm25': 28.78656639874839, 'reranker': 0.0, 'matched_terms': ('apply', 'argocdappoutofsync', 'by', 'conflict', 'field', 'manager', 'outofsync', 'server', 'side')}, {'key': 'kargo_verification_failing', 'bm25': 7.163116678810919, 'reranker': 0.0, 'matched_terms': ('blocked', 'promotion')}, {'key': 'outbox_not_draining', 'bm25': 1.8198454615906146, 'reranker': 0.0, 'matched_terms': ('blocked',)}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'argocd_app_stuck_outofsync', 'bm25': 28.78656639874839, 'reranker': 0.0, 'matched_terms': ('apply', 'argocdappoutofsync', 'by', 'conflict', 'field', 'manager', 'outofsync', 'server', 'side')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'argocd_app_stuck_outofsync', 'bm25': 28.78656639874839, 'reranker': 0.0, 'matched_terms': ('apply', 'argocdappoutofsync', 'by', 'conflict', 'field', 'manager', 'outofsync', 'server', 'side')}, {'key': 'kargo_verification_failing', 'bm25': 7.163116678810919, 'reranker': 0.0, 'matched_terms': ('blocked', 'promotion')}, {'key': 'outbox_not_draining', 'bm25': 1.8198454615906146, 'reranker': 0.0, 'matched_terms': ('blocked',)}], 'raw_reranker_candidates': [{'key': 'argocd_app_stuck_outofsync', 'bm25': 28.78656639874839, 'reranker': 6.594336986541748, 'matched_terms': ('apply', 'argocdappoutofsync', 'by', 'conflict', 'field', 'manager', 'outofsync', 'server', 'side')}, {'key': 'outbox_not_draining', 'bm25': 1.8198454615906146, 'reranker': 1.7741059064865112, 'matched_terms': ('blocked',)}, {'key': 'kargo_verification_failing', 'bm25': 7.163116678810919, 'reranker': 1.7291978597640991, 'matched_terms': ('blocked', 'promotion')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'argocd_app_stuck_outofsync', 'bm25': 28.78656639874839, 'reranker': 0.0, 'matched_terms': ('apply', 'argocdappoutofsync', 'by', 'conflict', 'field', 'manager', 'outofsync', 'server', 'side')}, {'key': 'kargo_verification_failing', 'bm25': 7.163116678810919, 'reranker': 0.0, 'matched_terms': ('blocked', 'promotion')}, {'key': 'outbox_not_draining', 'bm25': 1.8198454615906146, 'reranker': 0.0, 'matched_terms': ('blocked',)}], 'raw_reranker_candidates': [{'key': 'argocd_app_stuck_outofsync', 'bm25': 28.78656639874839, 'reranker': 0.5028536319732666, 'matched_terms': ('apply', 'argocdappoutofsync', 'by', 'conflict', 'field', 'manager', 'outofsync', 'server', 'side')}, {'key': 'outbox_not_draining', 'bm25': 1.8198454615906146, 'reranker': 0.0794801339507103, 'matched_terms': ('blocked',)}, {'key': 'kargo_verification_failing', 'bm25': 7.163116678810919, 'reranker': -0.44872763752937317, 'matched_terms': ('blocked', 'promotion')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# semantic_driver_after_redis_restart: expected=('driver_matching_returns_0_results',); competitors=('outbox_not_draining',)
# BM25 only {'bm25_candidates': [{'key': 'driver_matching_returns_0_results', 'bm25': 17.303520555555085, 'reranker': 0.0, 'matched_terms': ('available', 'drivermatchfailure', 'empty', 'geo', 'is', 'redis', 'restarted')}, {'key': 'outbox_not_draining', 'bm25': 9.162035214974724, 'reranker': 0.0, 'matched_terms': ('and', 'is', 'pending', 'redis', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 8.541718375375753, 'reranker': 0.0, 'matched_terms': ('and', 'dispatch', 'is', 'pending', 'the')}], 'raw_reranker_candidates': [{'key': 'driver_matching_returns_0_results', 'bm25': 17.303520555555085, 'reranker': 0.0, 'matched_terms': ('available', 'drivermatchfailure', 'empty', 'geo', 'is', 'redis', 'restarted')}, {'key': 'outbox_not_draining', 'bm25': 9.162035214974724, 'reranker': 0.0, 'matched_terms': ('and', 'is', 'pending', 'redis', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 8.541718375375753, 'reranker': 0.0, 'matched_terms': ('and', 'dispatch', 'is', 'pending', 'the')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'driver_matching_returns_0_results', 'bm25': 17.303520555555085, 'reranker': 0.0, 'matched_terms': ('available', 'drivermatchfailure', 'empty', 'geo', 'is', 'redis', 'restarted')}, {'key': 'outbox_not_draining', 'bm25': 9.162035214974724, 'reranker': 0.0, 'matched_terms': ('and', 'is', 'pending', 'redis', 'the')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'driver_matching_returns_0_results', 'bm25': 17.303520555555085, 'reranker': 0.0, 'matched_terms': ('available', 'drivermatchfailure', 'empty', 'geo', 'is', 'redis', 'restarted')}, {'key': 'outbox_not_draining', 'bm25': 9.162035214974724, 'reranker': 0.0, 'matched_terms': ('and', 'is', 'pending', 'redis', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 8.541718375375753, 'reranker': 0.0, 'matched_terms': ('and', 'dispatch', 'is', 'pending', 'the')}], 'raw_reranker_candidates': [{'key': 'driver_matching_returns_0_results', 'bm25': 17.303520555555085, 'reranker': 6.638994216918945, 'matched_terms': ('available', 'drivermatchfailure', 'empty', 'geo', 'is', 'redis', 'restarted')}, {'key': 'trip_offer_timeout_storm', 'bm25': 6.174815552149099, 'reranker': 4.684547424316406, 'matched_terms': ('available', 'dispatch', 'is', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 8.541718375375753, 'reranker': 3.0470893383026123, 'matched_terms': ('and', 'dispatch', 'is', 'pending', 'the')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'driver_matching_returns_0_results', 'bm25': 17.303520555555085, 'reranker': 0.0, 'matched_terms': ('available', 'drivermatchfailure', 'empty', 'geo', 'is', 'redis', 'restarted')}, {'key': 'outbox_not_draining', 'bm25': 9.162035214974724, 'reranker': 0.0, 'matched_terms': ('and', 'is', 'pending', 'redis', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 8.541718375375753, 'reranker': 0.0, 'matched_terms': ('and', 'dispatch', 'is', 'pending', 'the')}], 'raw_reranker_candidates': [{'key': 'driver_matching_returns_0_results', 'bm25': 17.303520555555085, 'reranker': 0.27284055948257446, 'matched_terms': ('available', 'drivermatchfailure', 'empty', 'geo', 'is', 'redis', 'restarted')}, {'key': 'outbox_not_draining', 'bm25': 9.162035214974724, 'reranker': -0.15575098991394043, 'matched_terms': ('and', 'is', 'pending', 'redis', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 8.541718375375753, 'reranker': 0.16720813512802124, 'matched_terms': ('and', 'dispatch', 'is', 'pending', 'the')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# semantic_idle_consumer_recovery: expected=('xautoclaim_pel_backlog',); competitors=('outbox_not_draining',)
# BM25 only {'bm25_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 22.268384911587685, 'reranker': 0.0, 'matched_terms': ('a', 'acknowledgement', 'are', 'consumerbacklog', 'dispatch', 'entries', 'idle', 'pending', 'stream', 'worker')}, {'key': 'outbox_not_draining', 'bm25': 8.0107405669277, 'reranker': 0.0, 'matched_terms': ('are', 'pending', 'stream', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.0, 'matched_terms': ('a', 'after', 'restart')}], 'raw_reranker_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 22.268384911587685, 'reranker': 0.0, 'matched_terms': ('a', 'acknowledgement', 'are', 'consumerbacklog', 'dispatch', 'entries', 'idle', 'pending', 'stream', 'worker')}, {'key': 'outbox_not_draining', 'bm25': 8.0107405669277, 'reranker': 0.0, 'matched_terms': ('are', 'pending', 'stream', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.0, 'matched_terms': ('a', 'after', 'restart')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 22.268384911587685, 'reranker': 0.0, 'matched_terms': ('a', 'acknowledgement', 'are', 'consumerbacklog', 'dispatch', 'entries', 'idle', 'pending', 'stream', 'worker')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 22.268384911587685, 'reranker': 0.0, 'matched_terms': ('a', 'acknowledgement', 'are', 'consumerbacklog', 'dispatch', 'entries', 'idle', 'pending', 'stream', 'worker')}, {'key': 'outbox_not_draining', 'bm25': 8.0107405669277, 'reranker': 0.0, 'matched_terms': ('are', 'pending', 'stream', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.0, 'matched_terms': ('a', 'after', 'restart')}], 'raw_reranker_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 22.268384911587685, 'reranker': 7.08432149887085, 'matched_terms': ('a', 'acknowledgement', 'are', 'consumerbacklog', 'dispatch', 'entries', 'idle', 'pending', 'stream', 'worker')}, {'key': 'outbox_not_draining', 'bm25': 8.0107405669277, 'reranker': 4.571115016937256, 'matched_terms': ('are', 'pending', 'stream', 'worker')}, {'key': 'trip_offer_timeout_storm', 'bm25': 4.779094420365306, 'reranker': 3.438559055328369, 'matched_terms': ('after', 'are', 'dispatch')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 22.268384911587685, 'reranker': 0.0, 'matched_terms': ('a', 'acknowledgement', 'are', 'consumerbacklog', 'dispatch', 'entries', 'idle', 'pending', 'stream', 'worker')}, {'key': 'outbox_not_draining', 'bm25': 8.0107405669277, 'reranker': 0.0, 'matched_terms': ('are', 'pending', 'stream', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.0, 'matched_terms': ('a', 'after', 'restart')}], 'raw_reranker_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 22.268384911587685, 'reranker': 0.995851993560791, 'matched_terms': ('a', 'acknowledgement', 'are', 'consumerbacklog', 'dispatch', 'entries', 'idle', 'pending', 'stream', 'worker')}, {'key': 'outbox_not_draining', 'bm25': 8.0107405669277, 'reranker': 0.12605857849121094, 'matched_terms': ('are', 'pending', 'stream', 'worker')}, {'key': 'trip_offer_timeout_storm', 'bm25': 4.779094420365306, 'reranker': 0.08680076897144318, 'matched_terms': ('after', 'are', 'dispatch')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 22.268384911587685, 'reranker': 0.995851993560791, 'matched_terms': ('a', 'acknowledgement', 'are', 'consumerbacklog', 'dispatch', 'entries', 'idle', 'pending', 'stream', 'worker')}]}
#
# semantic_dispatch_deadline: expected=('trip_offer_timeout_storm',); competitors=('xautoclaim_pel_backlog',)
# BM25 only {'bm25_candidates': [{'key': 'trip_offer_timeout_storm', 'bm25': 23.063694782229863, 'reranker': 0.0, 'matched_terms': ('at', 'cancelled', 'deadline', 'dispatch', 'is', 'no', 'offer', 'second', 'ten', 'the', 'tripfailure')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 6.8097632465534375, 'reranker': 0.0, 'matched_terms': ('dispatch', 'is', 'pending', 'the')}, {'key': 'outbox_not_draining', 'bm25': 5.258215328780098, 'reranker': 0.0, 'matched_terms': ('no', 'pending')}], 'raw_reranker_candidates': [{'key': 'trip_offer_timeout_storm', 'bm25': 23.063694782229863, 'reranker': 0.0, 'matched_terms': ('at', 'cancelled', 'deadline', 'dispatch', 'is', 'no', 'offer', 'second', 'ten', 'the', 'tripfailure')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 6.8097632465534375, 'reranker': 0.0, 'matched_terms': ('dispatch', 'is', 'pending', 'the')}, {'key': 'outbox_not_draining', 'bm25': 5.258215328780098, 'reranker': 0.0, 'matched_terms': ('no', 'pending')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'trip_offer_timeout_storm', 'bm25': 23.063694782229863, 'reranker': 0.0, 'matched_terms': ('at', 'cancelled', 'deadline', 'dispatch', 'is', 'no', 'offer', 'second', 'ten', 'the', 'tripfailure')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'trip_offer_timeout_storm', 'bm25': 23.063694782229863, 'reranker': 0.0, 'matched_terms': ('at', 'cancelled', 'deadline', 'dispatch', 'is', 'no', 'offer', 'second', 'ten', 'the', 'tripfailure')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 6.8097632465534375, 'reranker': 0.0, 'matched_terms': ('dispatch', 'is', 'pending', 'the')}, {'key': 'outbox_not_draining', 'bm25': 5.258215328780098, 'reranker': 0.0, 'matched_terms': ('no', 'pending')}], 'raw_reranker_candidates': [{'key': 'trip_offer_timeout_storm', 'bm25': 23.063694782229863, 'reranker': 7.227721214294434, 'matched_terms': ('at', 'cancelled', 'deadline', 'dispatch', 'is', 'no', 'offer', 'second', 'ten', 'the', 'tripfailure')}, {'key': 'driver_matching_returns_0_results', 'bm25': 1.5167756773611427, 'reranker': 5.040304660797119, 'matched_terms': ('is',)}, {'key': 'xautoclaim_pel_backlog', 'bm25': 6.8097632465534375, 'reranker': 4.159876346588135, 'matched_terms': ('dispatch', 'is', 'pending', 'the')}], 'score_floor': 7.159183502197266, 'accepted_candidates': [{'key': 'trip_offer_timeout_storm', 'bm25': 23.063694782229863, 'reranker': 7.227721214294434, 'matched_terms': ('at', 'cancelled', 'deadline', 'dispatch', 'is', 'no', 'offer', 'second', 'ten', 'the', 'tripfailure')}]}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'trip_offer_timeout_storm', 'bm25': 23.063694782229863, 'reranker': 0.0, 'matched_terms': ('at', 'cancelled', 'deadline', 'dispatch', 'is', 'no', 'offer', 'second', 'ten', 'the', 'tripfailure')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 6.8097632465534375, 'reranker': 0.0, 'matched_terms': ('dispatch', 'is', 'pending', 'the')}, {'key': 'outbox_not_draining', 'bm25': 5.258215328780098, 'reranker': 0.0, 'matched_terms': ('no', 'pending')}], 'raw_reranker_candidates': [{'key': 'trip_offer_timeout_storm', 'bm25': 23.063694782229863, 'reranker': 0.46362581849098206, 'matched_terms': ('at', 'cancelled', 'deadline', 'dispatch', 'is', 'no', 'offer', 'second', 'ten', 'the', 'tripfailure')}, {'key': 'deployment_scaled_to_zero', 'bm25': 2.6462619150877726, 'reranker': -0.2602565586566925, 'matched_terms': ('no',)}, {'key': 'zero_replica', 'bm25': 2.6462619150877726, 'reranker': -0.2602565586566925, 'matched_terms': ('no',)}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# semantic_unschedulable_capacity: expected=('failed_scheduling',); competitors=('xautoclaim_pel_backlog',)
# BM25 only {'bm25_candidates': [{'key': 'failed_scheduling', 'bm25': 24.145751395120804, 'reranker': 0.0, 'matched_terms': ('and', 'failedscheduling', 'kubepodnotscheduled', 'node', 'prevent', 'request', 'resource', 'scheduling', 'taint')}, {'key': 'oom', 'bm25': 8.687566425772285, 'reranker': 0.0, 'matched_terms': ('and', 'node', 'pod', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 5.189722544378245, 'reranker': 0.0, 'matched_terms': ('and', 'pending', 'the')}], 'raw_reranker_candidates': [{'key': 'failed_scheduling', 'bm25': 24.145751395120804, 'reranker': 0.0, 'matched_terms': ('and', 'failedscheduling', 'kubepodnotscheduled', 'node', 'prevent', 'request', 'resource', 'scheduling', 'taint')}, {'key': 'oom', 'bm25': 8.687566425772285, 'reranker': 0.0, 'matched_terms': ('and', 'node', 'pod', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 5.189722544378245, 'reranker': 0.0, 'matched_terms': ('and', 'pending', 'the')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'failed_scheduling', 'bm25': 24.145751395120804, 'reranker': 0.0, 'matched_terms': ('and', 'failedscheduling', 'kubepodnotscheduled', 'node', 'prevent', 'request', 'resource', 'scheduling', 'taint')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'failed_scheduling', 'bm25': 24.145751395120804, 'reranker': 0.0, 'matched_terms': ('and', 'failedscheduling', 'kubepodnotscheduled', 'node', 'prevent', 'request', 'resource', 'scheduling', 'taint')}, {'key': 'oom', 'bm25': 8.687566425772285, 'reranker': 0.0, 'matched_terms': ('and', 'node', 'pod', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 5.189722544378245, 'reranker': 0.0, 'matched_terms': ('and', 'pending', 'the')}], 'raw_reranker_candidates': [{'key': 'failed_scheduling', 'bm25': 24.145751395120804, 'reranker': 6.324461936950684, 'matched_terms': ('and', 'failedscheduling', 'kubepodnotscheduled', 'node', 'prevent', 'request', 'resource', 'scheduling', 'taint')}, {'key': 'oom', 'bm25': 8.687566425772285, 'reranker': 5.502804279327393, 'matched_terms': ('and', 'node', 'pod', 'the')}, {'key': 'kargo_verification_failing', 'bm25': 1.9859588241415256, 'reranker': 2.391714096069336, 'matched_terms': ('the',)}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'failed_scheduling', 'bm25': 24.145751395120804, 'reranker': 0.0, 'matched_terms': ('and', 'failedscheduling', 'kubepodnotscheduled', 'node', 'prevent', 'request', 'resource', 'scheduling', 'taint')}, {'key': 'oom', 'bm25': 8.687566425772285, 'reranker': 0.0, 'matched_terms': ('and', 'node', 'pod', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 5.189722544378245, 'reranker': 0.0, 'matched_terms': ('and', 'pending', 'the')}], 'raw_reranker_candidates': [{'key': 'failed_scheduling', 'bm25': 24.145751395120804, 'reranker': 0.6965822577476501, 'matched_terms': ('and', 'failedscheduling', 'kubepodnotscheduled', 'node', 'prevent', 'request', 'resource', 'scheduling', 'taint')}, {'key': 'oom', 'bm25': 8.687566425772285, 'reranker': -0.0069002085365355015, 'matched_terms': ('and', 'node', 'pod', 'the')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 5.189722544378245, 'reranker': -0.20213750004768372, 'matched_terms': ('and', 'pending', 'the')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# stress_config_diff_before_crash: expected=('config_error',); competitors=('crashloop', 'init_crashloop')
# BM25 only {'bm25_candidates': [{'key': 'crashloop', 'bm25': 17.026748004117383, 'reranker': 0.0, 'matched_terms': ('an', 'application', 'configuration', 'container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'missing', 'startup')}, {'key': 'init_crashloop', 'bm25': 12.21503481955424, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'config_error', 'bm25': 6.576169327611767, 'reranker': 0.0, 'matched_terms': ('kubepodcontainerwaiting', 'missing')}], 'raw_reranker_candidates': [{'key': 'crashloop', 'bm25': 17.026748004117383, 'reranker': 0.0, 'matched_terms': ('an', 'application', 'configuration', 'container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'missing', 'startup')}, {'key': 'init_crashloop', 'bm25': 12.21503481955424, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'config_error', 'bm25': 6.576169327611767, 'reranker': 0.0, 'matched_terms': ('kubepodcontainerwaiting', 'missing')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'crashloop', 'bm25': 17.026748004117383, 'reranker': 0.0, 'matched_terms': ('an', 'application', 'configuration', 'container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'missing', 'startup')}, {'key': 'init_crashloop', 'bm25': 12.21503481955424, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'crashloop', 'bm25': 17.026748004117383, 'reranker': 0.0, 'matched_terms': ('an', 'application', 'configuration', 'container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'missing', 'startup')}, {'key': 'init_crashloop', 'bm25': 12.21503481955424, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'config_error', 'bm25': 6.576169327611767, 'reranker': 0.0, 'matched_terms': ('kubepodcontainerwaiting', 'missing')}], 'raw_reranker_candidates': [{'key': 'crashloop', 'bm25': 17.026748004117383, 'reranker': 5.47624397277832, 'matched_terms': ('an', 'application', 'configuration', 'container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'missing', 'startup')}, {'key': 'init_crashloop', 'bm25': 12.21503481955424, 'reranker': 5.510794162750244, 'matched_terms': ('container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'config_error', 'bm25': 6.576169327611767, 'reranker': 4.97752046585083, 'matched_terms': ('kubepodcontainerwaiting', 'missing')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'crashloop', 'bm25': 17.026748004117383, 'reranker': 0.0, 'matched_terms': ('an', 'application', 'configuration', 'container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'missing', 'startup')}, {'key': 'init_crashloop', 'bm25': 12.21503481955424, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'config_error', 'bm25': 6.576169327611767, 'reranker': 0.0, 'matched_terms': ('kubepodcontainerwaiting', 'missing')}], 'raw_reranker_candidates': [{'key': 'crashloop', 'bm25': 17.026748004117383, 'reranker': 0.35483816266059875, 'matched_terms': ('an', 'application', 'configuration', 'container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'missing', 'startup')}, {'key': 'init_crashloop', 'bm25': 12.21503481955424, 'reranker': 0.4092397093772888, 'matched_terms': ('container', 'crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'config_error', 'bm25': 6.576169327611767, 'reranker': 0.1570570468902588, 'matched_terms': ('kubepodcontainerwaiting', 'missing')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# stress_init_memory_vs_app_memory: expected=('init_oom',); competitors=('oom', 'init_crashloop')
# BM25 only {'bm25_candidates': [{'key': 'oom', 'bm25': 17.542919738278265, 'reranker': 0.0, 'matched_terms': ('exceeded', 'kubepodcontainerterminated', 'limit', 'memory', 'oomkilled')}, {'key': 'init_oom', 'bm25': 15.31222194300052, 'reranker': 0.0, 'matched_terms': ('container', 'init', 'kubepodcontainerterminated', 'oomkilled')}, {'key': 'init_crashloop', 'bm25': 7.546317896385477, 'reranker': 0.0, 'matched_terms': ('container', 'init')}], 'raw_reranker_candidates': [{'key': 'oom', 'bm25': 17.542919738278265, 'reranker': 0.0, 'matched_terms': ('exceeded', 'kubepodcontainerterminated', 'limit', 'memory', 'oomkilled')}, {'key': 'init_oom', 'bm25': 15.31222194300052, 'reranker': 0.0, 'matched_terms': ('container', 'init', 'kubepodcontainerterminated', 'oomkilled')}, {'key': 'init_crashloop', 'bm25': 7.546317896385477, 'reranker': 0.0, 'matched_terms': ('container', 'init')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'oom', 'bm25': 17.542919738278265, 'reranker': 0.0, 'matched_terms': ('exceeded', 'kubepodcontainerterminated', 'limit', 'memory', 'oomkilled')}, {'key': 'init_oom', 'bm25': 15.31222194300052, 'reranker': 0.0, 'matched_terms': ('container', 'init', 'kubepodcontainerterminated', 'oomkilled')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'oom', 'bm25': 17.542919738278265, 'reranker': 0.0, 'matched_terms': ('exceeded', 'kubepodcontainerterminated', 'limit', 'memory', 'oomkilled')}, {'key': 'init_oom', 'bm25': 15.31222194300052, 'reranker': 0.0, 'matched_terms': ('container', 'init', 'kubepodcontainerterminated', 'oomkilled')}, {'key': 'init_crashloop', 'bm25': 7.546317896385477, 'reranker': 0.0, 'matched_terms': ('container', 'init')}], 'raw_reranker_candidates': [{'key': 'oom', 'bm25': 17.542919738278265, 'reranker': 6.484365463256836, 'matched_terms': ('exceeded', 'kubepodcontainerterminated', 'limit', 'memory', 'oomkilled')}, {'key': 'init_oom', 'bm25': 15.31222194300052, 'reranker': 6.1474833488464355, 'matched_terms': ('container', 'init', 'kubepodcontainerterminated', 'oomkilled')}, {'key': 'init_crashloop', 'bm25': 7.546317896385477, 'reranker': 4.881594657897949, 'matched_terms': ('container', 'init')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'oom', 'bm25': 17.542919738278265, 'reranker': 0.0, 'matched_terms': ('exceeded', 'kubepodcontainerterminated', 'limit', 'memory', 'oomkilled')}, {'key': 'init_oom', 'bm25': 15.31222194300052, 'reranker': 0.0, 'matched_terms': ('container', 'init', 'kubepodcontainerterminated', 'oomkilled')}, {'key': 'init_crashloop', 'bm25': 7.546317896385477, 'reranker': 0.0, 'matched_terms': ('container', 'init')}], 'raw_reranker_candidates': [{'key': 'oom', 'bm25': 17.542919738278265, 'reranker': 0.47823840379714966, 'matched_terms': ('exceeded', 'kubepodcontainerterminated', 'limit', 'memory', 'oomkilled')}, {'key': 'init_oom', 'bm25': 15.31222194300052, 'reranker': 0.5390394330024719, 'matched_terms': ('container', 'init', 'kubepodcontainerterminated', 'oomkilled')}, {'key': 'init_crashloop', 'bm25': 7.546317896385477, 'reranker': 0.161305233836174, 'matched_terms': ('container', 'init')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# stress_image_registry_vs_config: expected=('image_pull',); competitors=('config_error', 'crashloop')
# BM25 only {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 9.010745161868867, 'reranker': 0.0, 'matched_terms': ('failed', 'kubepodcontainerwaiting', 'startup')}, {'key': 'image_pull', 'bm25': 7.7573999965454545, 'reranker': 0.0, 'matched_terms': ('imagepullbackoff', 'kubepodcontainerwaiting')}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 9.010745161868867, 'reranker': 0.0, 'matched_terms': ('failed', 'kubepodcontainerwaiting', 'startup')}, {'key': 'image_pull', 'bm25': 7.7573999965454545, 'reranker': 0.0, 'matched_terms': ('imagepullbackoff', 'kubepodcontainerwaiting')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 9.010745161868867, 'reranker': 0.0, 'matched_terms': ('failed', 'kubepodcontainerwaiting', 'startup')}, {'key': 'image_pull', 'bm25': 7.7573999965454545, 'reranker': 0.0, 'matched_terms': ('imagepullbackoff', 'kubepodcontainerwaiting')}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 6.0407633781433105, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 9.010745161868867, 'reranker': 6.1606645584106445, 'matched_terms': ('failed', 'kubepodcontainerwaiting', 'startup')}, {'key': 'image_pull', 'bm25': 7.7573999965454545, 'reranker': 5.555098056793213, 'matched_terms': ('imagepullbackoff', 'kubepodcontainerwaiting')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 9.010745161868867, 'reranker': 0.0, 'matched_terms': ('failed', 'kubepodcontainerwaiting', 'startup')}, {'key': 'image_pull', 'bm25': 7.7573999965454545, 'reranker': 0.0, 'matched_terms': ('imagepullbackoff', 'kubepodcontainerwaiting')}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.2745901346206665, 'matched_terms': ('container', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 9.010745161868867, 'reranker': 0.34966397285461426, 'matched_terms': ('failed', 'kubepodcontainerwaiting', 'startup')}, {'key': 'image_pull', 'bm25': 7.7573999965454545, 'reranker': 0.32074910402297974, 'matched_terms': ('imagepullbackoff', 'kubepodcontainerwaiting')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# stress_scale_zero_vs_scheduler: expected=('deployment_scaled_to_zero',); competitors=('failed_scheduling', 'zero_replica')
# BM25 only {'bm25_candidates': [{'key': 'deployment_scaled_to_zero', 'bm25': 18.993406349741857, 'reranker': 0.0, 'matched_terms': ('deployment', 'no', 'pods', 'replicas', 'servicedown', 'to', 'traffic', 'zero')}, {'key': 'zero_replica', 'bm25': 10.125264829195462, 'reranker': 0.0, 'matched_terms': ('no', 'servicedown', 'traffic')}, {'key': 'trip_offer_timeout_storm', 'bm25': 8.742850717562876, 'reranker': 0.0, 'matched_terms': ('are', 'available', 'from', 'no', 'to')}], 'raw_reranker_candidates': [{'key': 'deployment_scaled_to_zero', 'bm25': 18.993406349741857, 'reranker': 0.0, 'matched_terms': ('deployment', 'no', 'pods', 'replicas', 'servicedown', 'to', 'traffic', 'zero')}, {'key': 'zero_replica', 'bm25': 10.125264829195462, 'reranker': 0.0, 'matched_terms': ('no', 'servicedown', 'traffic')}, {'key': 'trip_offer_timeout_storm', 'bm25': 8.742850717562876, 'reranker': 0.0, 'matched_terms': ('are', 'available', 'from', 'no', 'to')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'deployment_scaled_to_zero', 'bm25': 18.993406349741857, 'reranker': 0.0, 'matched_terms': ('deployment', 'no', 'pods', 'replicas', 'servicedown', 'to', 'traffic', 'zero')}, {'key': 'zero_replica', 'bm25': 10.125264829195462, 'reranker': 0.0, 'matched_terms': ('no', 'servicedown', 'traffic')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'deployment_scaled_to_zero', 'bm25': 18.993406349741857, 'reranker': 0.0, 'matched_terms': ('deployment', 'no', 'pods', 'replicas', 'servicedown', 'to', 'traffic', 'zero')}, {'key': 'zero_replica', 'bm25': 10.125264829195462, 'reranker': 0.0, 'matched_terms': ('no', 'servicedown', 'traffic')}, {'key': 'trip_offer_timeout_storm', 'bm25': 8.742850717562876, 'reranker': 0.0, 'matched_terms': ('are', 'available', 'from', 'no', 'to')}], 'raw_reranker_candidates': [{'key': 'deployment_scaled_to_zero', 'bm25': 18.993406349741857, 'reranker': 6.117060661315918, 'matched_terms': ('deployment', 'no', 'pods', 'replicas', 'servicedown', 'to', 'traffic', 'zero')}, {'key': 'zero_replica', 'bm25': 10.125264829195462, 'reranker': 4.52678108215332, 'matched_terms': ('no', 'servicedown', 'traffic')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 1.6417821751914763, 'reranker': 2.4653983116149902, 'matched_terms': ('are',)}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'deployment_scaled_to_zero', 'bm25': 18.993406349741857, 'reranker': 0.0, 'matched_terms': ('deployment', 'no', 'pods', 'replicas', 'servicedown', 'to', 'traffic', 'zero')}, {'key': 'zero_replica', 'bm25': 10.125264829195462, 'reranker': 0.0, 'matched_terms': ('no', 'servicedown', 'traffic')}, {'key': 'trip_offer_timeout_storm', 'bm25': 8.742850717562876, 'reranker': 0.0, 'matched_terms': ('are', 'available', 'from', 'no', 'to')}], 'raw_reranker_candidates': [{'key': 'deployment_scaled_to_zero', 'bm25': 18.993406349741857, 'reranker': 0.6188555955886841, 'matched_terms': ('deployment', 'no', 'pods', 'replicas', 'servicedown', 'to', 'traffic', 'zero')}, {'key': 'zero_replica', 'bm25': 10.125264829195462, 'reranker': 0.6628544330596924, 'matched_terms': ('no', 'servicedown', 'traffic')}, {'key': 'xautoclaim_pel_backlog', 'bm25': 1.6417821751914763, 'reranker': -0.1393069177865982, 'matched_terms': ('are',)}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# stress_promotion_latency_gate: expected=('kargo_verification_failing',); competitors=('high_error_rate_on_ride_service',)
# BM25 only {'bm25_candidates': [{'key': 'kargo_verification_failing', 'bm25': 22.945406059374246, 'reranker': 0.0, 'matched_terms': ('after', 'analysisrun', 'error', 'failed', 'latency', 'p99', 'promotion', 'regression', 'the')}, {'key': 'high_error_rate_on_ride_service', 'bm25': 9.542618964054423, 'reranker': 0.0, 'matched_terms': ('above', 'higherrorrate')}, {'key': 'crashloop', 'bm25': 4.8225224036712095, 'reranker': 0.0, 'matched_terms': ('after', 'an', 'error')}], 'raw_reranker_candidates': [{'key': 'kargo_verification_failing', 'bm25': 22.945406059374246, 'reranker': 0.0, 'matched_terms': ('after', 'analysisrun', 'error', 'failed', 'latency', 'p99', 'promotion', 'regression', 'the')}, {'key': 'high_error_rate_on_ride_service', 'bm25': 9.542618964054423, 'reranker': 0.0, 'matched_terms': ('above', 'higherrorrate')}, {'key': 'crashloop', 'bm25': 4.8225224036712095, 'reranker': 0.0, 'matched_terms': ('after', 'an', 'error')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'kargo_verification_failing', 'bm25': 22.945406059374246, 'reranker': 0.0, 'matched_terms': ('after', 'analysisrun', 'error', 'failed', 'latency', 'p99', 'promotion', 'regression', 'the')}, {'key': 'high_error_rate_on_ride_service', 'bm25': 9.542618964054423, 'reranker': 0.0, 'matched_terms': ('above', 'higherrorrate')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'kargo_verification_failing', 'bm25': 22.945406059374246, 'reranker': 0.0, 'matched_terms': ('after', 'analysisrun', 'error', 'failed', 'latency', 'p99', 'promotion', 'regression', 'the')}, {'key': 'high_error_rate_on_ride_service', 'bm25': 9.542618964054423, 'reranker': 0.0, 'matched_terms': ('above', 'higherrorrate')}, {'key': 'crashloop', 'bm25': 4.8225224036712095, 'reranker': 0.0, 'matched_terms': ('after', 'an', 'error')}], 'raw_reranker_candidates': [{'key': 'kargo_verification_failing', 'bm25': 22.945406059374246, 'reranker': 3.6975131034851074, 'matched_terms': ('after', 'analysisrun', 'error', 'failed', 'latency', 'p99', 'promotion', 'regression', 'the')}, {'key': 'high_error_rate_on_ride_service', 'bm25': 9.542618964054423, 'reranker': 3.5165421962738037, 'matched_terms': ('above', 'higherrorrate')}, {'key': 'trip_offer_timeout_storm', 'bm25': 3.9291780509346705, 'reranker': 1.9017620086669922, 'matched_terms': ('after', 'an', 'the')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'kargo_verification_failing', 'bm25': 22.945406059374246, 'reranker': 0.0, 'matched_terms': ('after', 'analysisrun', 'error', 'failed', 'latency', 'p99', 'promotion', 'regression', 'the')}, {'key': 'high_error_rate_on_ride_service', 'bm25': 9.542618964054423, 'reranker': 0.0, 'matched_terms': ('above', 'higherrorrate')}, {'key': 'crashloop', 'bm25': 4.8225224036712095, 'reranker': 0.0, 'matched_terms': ('after', 'an', 'error')}], 'raw_reranker_candidates': [{'key': 'high_error_rate_on_ride_service', 'bm25': 9.542618964054423, 'reranker': 0.41638243198394775, 'matched_terms': ('above', 'higherrorrate')}, {'key': 'kargo_verification_failing', 'bm25': 22.945406059374246, 'reranker': -0.44269368052482605, 'matched_terms': ('after', 'analysisrun', 'error', 'failed', 'latency', 'p99', 'promotion', 'regression', 'the')}, {'key': 'trip_offer_timeout_storm', 'bm25': 3.9291780509346705, 'reranker': -0.5153998136520386, 'matched_terms': ('after', 'an', 'the')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# stress_trace_error_vs_delivery_gate: expected=('crashloop',); competitors=('config_error', 'init_crashloop')
# BM25 only {'bm25_candidates': [{'key': 'crashloop', 'bm25': 14.679874835055433, 'reranker': 0.0, 'matched_terms': ('a', 'application', 'crashloopbackoff', 'dependency', 'error', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'kargo_verification_failing', 'bm25': 5.7425037025462755, 'reranker': 0.0, 'matched_terms': ('a', 'error', 'the')}], 'raw_reranker_candidates': [{'key': 'crashloop', 'bm25': 14.679874835055433, 'reranker': 0.0, 'matched_terms': ('a', 'application', 'crashloopbackoff', 'dependency', 'error', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'kargo_verification_failing', 'bm25': 5.7425037025462755, 'reranker': 0.0, 'matched_terms': ('a', 'error', 'the')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'crashloop', 'bm25': 14.679874835055433, 'reranker': 0.0, 'matched_terms': ('a', 'application', 'crashloopbackoff', 'dependency', 'error', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'crashloop', 'bm25': 14.679874835055433, 'reranker': 0.0, 'matched_terms': ('a', 'application', 'crashloopbackoff', 'dependency', 'error', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'kargo_verification_failing', 'bm25': 5.7425037025462755, 'reranker': 0.0, 'matched_terms': ('a', 'error', 'the')}], 'raw_reranker_candidates': [{'key': 'crashloop', 'bm25': 14.679874835055433, 'reranker': 4.828747749328613, 'matched_terms': ('a', 'application', 'crashloopbackoff', 'dependency', 'error', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 4.578310012817383, 'matched_terms': ('crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'oom', 'bm25': 3.72728804129261, 'reranker': 3.8878681659698486, 'matched_terms': ('connection', 'the')}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'crashloop', 'bm25': 14.679874835055433, 'reranker': 0.0, 'matched_terms': ('a', 'application', 'crashloopbackoff', 'dependency', 'error', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.0, 'matched_terms': ('crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'kargo_verification_failing', 'bm25': 5.7425037025462755, 'reranker': 0.0, 'matched_terms': ('a', 'error', 'the')}], 'raw_reranker_candidates': [{'key': 'crashloop', 'bm25': 14.679874835055433, 'reranker': 0.9051064252853394, 'matched_terms': ('a', 'application', 'crashloopbackoff', 'dependency', 'error', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_crashloop', 'bm25': 9.139915471922995, 'reranker': 0.7599454522132874, 'matched_terms': ('crashloopbackoff', 'kubepodcontainerwaiting', 'startup')}, {'key': 'oom', 'bm25': 3.72728804129261, 'reranker': 0.48708203434944153, 'matched_terms': ('connection', 'the')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': [{'key': 'crashloop', 'bm25': 14.679874835055433, 'reranker': 0.9051064252853394, 'matched_terms': ('a', 'application', 'crashloopbackoff', 'dependency', 'error', 'kubepodcontainerwaiting', 'startup')}]}
#
# stress_sparse_queue_recovery: expected=('xautoclaim_pel_backlog',); competitors=('outbox_not_draining',)
# BM25 only {'bm25_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 4.965307545549081, 'reranker': 0.0, 'matched_terms': ('a', 'pending', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.0, 'matched_terms': ('a', 'after', 'restart')}, {'key': 'outbox_not_draining', 'bm25': 3.6611429970876346, 'reranker': 0.0, 'matched_terms': ('pending', 'worker')}], 'raw_reranker_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 4.965307545549081, 'reranker': 0.0, 'matched_terms': ('a', 'pending', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.0, 'matched_terms': ('a', 'after', 'restart')}, {'key': 'outbox_not_draining', 'bm25': 3.6611429970876346, 'reranker': 0.0, 'matched_terms': ('pending', 'worker')}], 'score_floor': 9.139915471922995, 'accepted_candidates': []}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 4.965307545549081, 'reranker': 0.0, 'matched_terms': ('a', 'pending', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.0, 'matched_terms': ('a', 'after', 'restart')}, {'key': 'outbox_not_draining', 'bm25': 3.6611429970876346, 'reranker': 0.0, 'matched_terms': ('pending', 'worker')}], 'raw_reranker_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 4.965307545549081, 'reranker': 4.663277626037598, 'matched_terms': ('a', 'pending', 'worker')}, {'key': 'outbox_not_draining', 'bm25': 3.6611429970876346, 'reranker': 4.6264190673828125, 'matched_terms': ('pending', 'worker')}, {'key': 'oom', 'bm25': 1.6992506911218883, 'reranker': 4.347651958465576, 'matched_terms': ('worker',)}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 4.965307545549081, 'reranker': 0.0, 'matched_terms': ('a', 'pending', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.0, 'matched_terms': ('a', 'after', 'restart')}, {'key': 'outbox_not_draining', 'bm25': 3.6611429970876346, 'reranker': 0.0, 'matched_terms': ('pending', 'worker')}], 'raw_reranker_candidates': [{'key': 'xautoclaim_pel_backlog', 'bm25': 4.965307545549081, 'reranker': 0.6935016512870789, 'matched_terms': ('a', 'pending', 'worker')}, {'key': 'driver_matching_returns_0_results', 'bm25': 4.857754676724286, 'reranker': 0.346307635307312, 'matched_terms': ('a', 'after', 'restart')}, {'key': 'outbox_not_draining', 'bm25': 3.6611429970876346, 'reranker': 0.5350532531738281, 'matched_terms': ('pending', 'worker')}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}
#
# stress_crashloop_trace_configuration: expected=('crashloop',); competitors=('config_error', 'init_crashloop')
# BM25 only {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 16.565459013897144, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'failure', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 14.389875511599545, 'reranker': 0.0, 'matched_terms': ('after', 'application', 'container', 'crashloopbackoff', 'dependency', 'kubepodcontainerwaiting', 'startup')}, {'key': 'trip_offer_timeout_storm', 'bm25': 4.573668336677885, 'reranker': 0.0, 'matched_terms': ('after', 'is', 'to')}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 16.565459013897144, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'failure', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 14.389875511599545, 'reranker': 0.0, 'matched_terms': ('after', 'application', 'container', 'crashloopbackoff', 'dependency', 'kubepodcontainerwaiting', 'startup')}, {'key': 'trip_offer_timeout_storm', 'bm25': 4.573668336677885, 'reranker': 0.0, 'matched_terms': ('after', 'is', 'to')}], 'score_floor': 9.139915471922995, 'accepted_candidates': [{'key': 'init_crashloop', 'bm25': 16.565459013897144, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'failure', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 14.389875511599545, 'reranker': 0.0, 'matched_terms': ('after', 'application', 'container', 'crashloopbackoff', 'dependency', 'kubepodcontainerwaiting', 'startup')}]}
# BM25 → MiniLM {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 16.565459013897144, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'failure', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 14.389875511599545, 'reranker': 0.0, 'matched_terms': ('after', 'application', 'container', 'crashloopbackoff', 'dependency', 'kubepodcontainerwaiting', 'startup')}, {'key': 'trip_offer_timeout_storm', 'bm25': 4.573668336677885, 'reranker': 0.0, 'matched_terms': ('after', 'is', 'to')}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 16.565459013897144, 'reranker': 5.68211030960083, 'matched_terms': ('container', 'crashloopbackoff', 'failure', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 14.389875511599545, 'reranker': 5.852092742919922, 'matched_terms': ('after', 'application', 'container', 'crashloopbackoff', 'dependency', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_oom', 'bm25': 3.5212308958926917, 'reranker': 4.822451591491699, 'matched_terms': ('container',)}], 'score_floor': 7.159183502197266, 'accepted_candidates': []}
# BM25 → Mixedbread {'bm25_candidates': [{'key': 'init_crashloop', 'bm25': 16.565459013897144, 'reranker': 0.0, 'matched_terms': ('container', 'crashloopbackoff', 'failure', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 14.389875511599545, 'reranker': 0.0, 'matched_terms': ('after', 'application', 'container', 'crashloopbackoff', 'dependency', 'kubepodcontainerwaiting', 'startup')}, {'key': 'trip_offer_timeout_storm', 'bm25': 4.573668336677885, 'reranker': 0.0, 'matched_terms': ('after', 'is', 'to')}], 'raw_reranker_candidates': [{'key': 'init_crashloop', 'bm25': 16.565459013897144, 'reranker': 0.6002358198165894, 'matched_terms': ('container', 'crashloopbackoff', 'failure', 'kubepodcontainerwaiting', 'startup')}, {'key': 'crashloop', 'bm25': 14.389875511599545, 'reranker': 0.46735015511512756, 'matched_terms': ('after', 'application', 'container', 'crashloopbackoff', 'dependency', 'kubepodcontainerwaiting', 'startup')}, {'key': 'init_oom', 'bm25': 3.5212308958926917, 'reranker': 0.28405335545539856, 'matched_terms': ('container',)}], 'score_floor': 0.8416229486465454, 'accepted_candidates': []}

# %% [markdown]
# ## 6. Safety gate and Operational metrics
#
# A local reranker must have no forbidden result, false positive, exact failure, or degraded result. It must also match or exceed BM25 ranking quality, stay below 1,000 ms p95 latency, and use at most 500 MB peak RSS. Each RSS value is measured in a fresh process, matching the archived tournament method.

# %%
baseline = results['bm25']
eligibility = {}
gate_results = {}
for name, result in results.items():
    gate_results[name] = evaluate_selection_gate(result, baseline=baseline, p95_ms=operations[name]['p95_ms'], peak_rss_mb=operations[name]['peak_rss_mb'])
    eligibility[name] = name != 'bm25' and gate_results[name].status == 'selected'
    print(f'{name:18} status={gate_results[name].status} deltas={gate_results[name].quality_deltas} reasons={gate_results[name].reasons or ("no material regression",)}')

metrics = ['artifact_mb', 'cold_load_ms', 'p95_ms', 'peak_rss_mb']
fig, axes = plt.subplots(1, 4, figsize=(16, 3.5))
for axis, metric in zip(axes, metrics):
    axis.bar(range(len(names)), [operations[name][metric] for name in names])
    axis.set_title(metric.replace('_', ' '))
    axis.set_xticks(range(len(names)), [display_names[name] for name in names])
    axis.tick_params(axis='x', rotation=30)
plt.tight_layout()
plt.show()

candidates = [name for name in names if name != 'bm25' and eligibility[name]]
if candidates:
    winner = min(candidates, key=lambda name: (operations[name]['p95_ms'], operations[name]['artifact_mb']))
    print(f'Decision: choose {display_names[winner]}; it passed the quality, safety, latency, and memory gates.')
else:
    print('Decision: inconclusive — BM25 remains a comparison baseline; no local reranker passed every gate.')
# Out:
# bm25               status=rejected deltas={'top1': 0.0, 'recall_at_3': 0.0, 'mrr': 0.0} reasons=('retrieval safety gate failed',)
# minilm             status=rejected deltas={'top1': -0.4, 'recall_at_3': -0.4, 'mrr': -0.4} reasons=('operational latency or memory gate failed', 'material retrieval-quality regression', 'small regression has no compensating quality gain')
# mixedbread_xsmall  status=rejected deltas={'top1': -0.7, 'recall_at_3': -0.7, 'mrr': -0.7} reasons=('operational latency or memory gate failed', 'material retrieval-quality regression', 'small regression has no compensating quality gain')
# Decision: inconclusive — BM25 remains a comparison baseline; no local reranker passed every gate.
